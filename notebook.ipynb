# %%
import pandas as pd 
import numpy as np
import seaborn as sns

# %%
data1=pd.read_csv('/home/jovyan/work/Admission_Predict_Ver1.1.csv')

# %%
data1.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
sns.scatterplot(x='GRE Score',y='TOEFL Score',hue='University Rating',data=data1)
# Out:
# <AxesSubplot:xlabel='GRE Score', ylabel='TOEFL Score'>

# %%
sns.regplot(x="GRE Score", y="Chance of Admit ",color="c",data=data1)
# Out:
# <AxesSubplot:xlabel='GRE Score', ylabel='Chance of Admit '>

# %%
sns.catplot(y="GRE Score", x="University Rating",kind="swarm", data=data1)

# %%
data1.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000         500.00000
# mean     3.48400    8.576440    0.560000           0.72174
# std      0.92545    0.604813    0.496884           0.14114
# min      1.00000    6.800000    0.000000           0.34000
# ...

# %%
x=data1[['GRE Score','TOEFL Score','University Rating','SOP','LOR ','CGPA',]]
y=data1[['Chance of Admit ']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regressor.score(X_test,y_test)
# Out:
# 0.8104078274545189
